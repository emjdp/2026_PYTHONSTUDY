# %% [markdown]
# <a href="https://colab.research.google.com/github/emjdp/2026_PYTHONSTUDY/blob/main/WEEK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HYPER Python Study - Coding Test
#
# ### 규칙
# - answer 변수에 결과를 저장하세요
# - print 사용하지 마세요
# - 코드 수정은 문제 셀에서만 하세요

# %%
import base64

class HYPER_Grader:
    def __init__(self):
        self.answers = {
            1: "NA==",
            2: "Mw==",
            3: "aGVsbG9fd29ybGQ=",
            4: "UG4=",
            5: "Mw=="
        }

    def check(self, task_id, user_answer):
      try:
          expected = base64.b64decode(self.answers[task_id]).decode()
          result = str(user_answer).strip()
          expected = expected.strip()

          if result == expected:
              print(f"Task {task_id}: ✅ 정답입니다!")
          else:
              print(f"Task {task_id}: ❌ 틀렸습니다.")
              print("당신의 출력:", result)
              print("정답:", expected)

      except Exception as e:
        print(f"Task {task_id}: ⚠ 에러 발생 ({e})")

grader = HYPER_Grader()
print("채점 준비 완료!")
# Out:
# 채점 준비 완료!

# %% [markdown]
# ## Task 1
#
# 문자열 `"hi"` 를 **2번 반복한 문자열의 길이**를 구하세요.

# %%
# 여기에 코드를 작성하세요

s = "hi"*2

answer = len(s)

# %%
grader.check(1, answer)
# Out:
# Task 1: ✅ 정답입니다!

# %% [markdown]
# ## Task 2
#
# 문자열 `"banana"` 에서 **'a'의 개수**를 구하세요.

# %%
s = "banana"

answer = s.count('a')

# %%
grader.check(2, answer)
# Out:
# Task 2: ✅ 정답입니다!

# %% [markdown]
# ## Task 3
#
# 두 문자열 `"Hello"` 와 `"World"` 를 **소문자로 바꾸고 `_` 로 연결하세요.**

# %%
a = "Hello"
b = "World"

answer = a.lower() + '_' + b.lower()

# %%
grader.check(3, answer)
# Out:
# Task 3: ✅ 정답입니다!

# %% [markdown]
# ## Task 4
#
# 문자열 `"Python"` 의 **첫 문자와 마지막 문자만 이어 붙이세요.**

# %%
s = "Python"

answer = s[0:7:5]

# %%
grader.check(4, answer)
# Out:
# Task 4: ✅ 정답입니다!

# %% [markdown]
# ## Task 5
#
# 문자열 `"I love python"` 을 공백 기준으로 나누었을 때 **단어의 개수**를 구하세요.

# %%
s = "I love python"

answer = len(s.split())

# %%
grader.check(5, answer)
# Out:
# Task 5: ✅ 정답입니다!
